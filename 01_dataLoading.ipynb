# %%
import pandas as pd
import numpy as np

# %%
import os
print(os.getcwd())
print(os.path.exists("../1_data/housePrice (1).csv"))
# Out:
# c:\Users\DELL\Documents\HousePricingProject[1]\03_notebooks
# True

# %%
import pandas as pd
#data loading
train_df = pd.read_csv("../1_data/housePrice (1).csv")

# %%
#visual inspection of the data
train_df.head()
# Out:
#   Area  Room  Parking  Warehouse  Elevator         Address       Price  \
# 0   63     1     True       True      True         Shahran  1850000000
# 1   60     1     True       True      True         Shahran  1850000000
# 2   79     2     True       True      True          Pardis   550000000
# 3   95     2     True       True      True   Shahrake Qods   902500000
# 4  123     2     True       True      True  Shahrake Gharb  7000000000
#
#    Price(USD)
# 0    61666.67
# 1    61666.67
# 2    18333.33
# 3    30083.33
# 4   233333.33

# %%
#understanding the dimensions of the data
train_df.shape
# Out:
# (3479, 8)

# %%
#getting a concise summary of the dataframe(columns, data types, missing values)
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3479 entries, 0 to 3478
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Area        3479 non-null   object
#  1   Room        3479 non-null   int64
#  2   Parking     3479 non-null   bool
#  3   Warehouse   3479 non-null   bool
#  4   Elevator    3479 non-null   bool
#  5   Address     3456 non-null   object
#  6   Price       3479 non-null   int64
#  7   Price(USD)  3479 non-null   float64
# dtypes: bool(3), float64(1), int64(2), object(2)
# memory usage: 146.2+ KB

# %%
#identifying the target variable
target = "Price"
"Price" in train_df.columns
# Out:
# True

# %%
#separating features and target variable
x= train_df.drop("Price", axis=1)
y = train_df["Price"]
x.shape, y.shape
# Out:
# ((3479, 7), (3479,))

# %%
#missing values in the dataset overview
train_df.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# Address       23
# Area           0
# Parking        0
# Room           0
# Warehouse      0
# Elevator       0
# Price          0
# Price(USD)     0
# dtype: int64

# %%
#feature types in the dataset
train_df.select_dtypes(include= 'object').columns
# Out:
# Index(['Area', 'Address'], dtype='object')

# %%
train_df.select_dtypes(exclude= 'object').columns
# Out:
# Index(['Room', 'Parking', 'Warehouse', 'Elevator', 'Price', 'Price(USD)'], dtype='object')
